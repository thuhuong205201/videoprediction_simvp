# %% [markdown]
# # Import lib

# %%
# !pip install addict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 549 kB 28.5 MB/s
# ...
#      |████████████████████████████████| 182 kB 76.0 MB/s
# ...

# %%
# !pip install constants
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for constants: filename=constants-0.6.0-py3-none-any.whl size=5473 sha256=3120284ef5c0e15b9ed41fae1b2ee4daf9b1466c0d08108144aea9570fadc22e
#   Stored in directory: /root/.cache/pip/wheels/77/ac/b2/89268490b92bf6fd0102b3634668042437e0e024c64ef447a1
# Successfully built constants
# ...

# %%
# !pip install fvcore
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 50 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.1 MB/s
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61431 sha256=4b10bec325654d818ecece49ce83fa282e4eab60f70db3cf98b9d731c620da11
#   Stored in directory: /root/.cache/pip/wheels/b8/79/07/c0e9367f5b5ea325e246bd73651e8af175fabbef943043b1cc
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=2ebdcf30c99c595ebb9d7323a9db9471c56bc26646f7df28763bc0ba48f9edb5
#   Stored in directory: /root/.cache/pip/wheels/89/3e/24/0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
# Successfully built fvcore iopath
# ...

# %%
# !pip install nni
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56.0 MB 326 kB/s
# ...
#      |████████████████████████████████| 106 kB 85.5 MB/s
# ...
#      |████████████████████████████████| 51 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 139 kB 87.7 MB/s
# ...
#      |████████████████████████████████| 127 kB 66.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !pip install hickle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 107 kB 35.3 MB/s
# ...

# %% [markdown]
# # code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/chengtan9907/SimVPv2.git
# Out:
# Cloning into 'SimVPv2'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 93 (delta 29), reused 87 (delta 26), pack-reused 0
# Unpacking objects: 100% (93/93), done.

# %%
# %cd '/content/SimVPv2'
# Out:
# /content/SimVPv2

# %%
# !python main.py
# Out:
# loading config from ./configs/SimVP.py ...
# Use GPU: cuda:0
#
# device: 	cuda
# display_step: 	10
# res_dir: 	./results
# ex_name: 	Debug
# use_gpu: 	True
# gpu: 	0
# seed: 	111
# batch_size: 	16
# val_batch_size: 	4
# num_workers: 	8
# data_root: 	/content/drive/MyDrive/Deep_learning/Final/datamnist/
# dataname: 	mmnist
# method: 	SimVP
# config_file: 	./configs/SimVP.py
# epoch: 	201
# log_step: 	1
# lr: 	0.001
# model_type: 	gSTA
# hid_S: 	64
# hid_T: 	512
# N_T: 	8
# N_S: 	4
# in_shape: 	[10, 1, 64, 64]
# pre_seq_length: 	10
# aft_seq_length: 	10
# total_length: 	20
# | module                           | #parameters or shape   | #flops     |
# |:---------------------------------|:-----------------------|:-----------|
# | model                            | 49.475M                | 16.533G    |
# |  enc.enc                         |  0.112M                |  0.893G    |
# |   enc.enc.0.conv                 |   0.768K               |   36.7M    |
# ...
